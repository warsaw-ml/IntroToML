# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from face_age_datamodule import FaceAgeDataModule, FaceAgeDataset
dataset = FaceAgeDataset(data_dir="data/")

# %%
print(dataset.images.shape)
print(dataset.labels.shape)
# Out:
# torch.Size([23708, 3, 100, 100])
# torch.Size([23708, 1])

# %%
df = pd.DataFrame(dataset.labels.numpy())
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23708 entries, 0 to 23707
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       23708 non-null  int64
# dtypes: int64(1)
# memory usage: 185.3 KB
# None

# %%
print(df.describe())
# Out:
#                   0
# count  23708.000000
# mean      33.303484
# std       19.886112
# min        1.000000
# 25%       23.000000
# 50%       29.000000
# 75%       45.000000
# max      116.000000

# %%
# plot age histogram with seaborn
sns.histplot(data=df)
plt.show()

# %%
from turtle import title
from torchvision import transforms

for i in range(5):
    img, label = dataset[i]
    plt.figure()
    print(int(label))
    plt.imshow(transforms.ToPILImage()(img), interpolation="bicubic")
# Out:
# 9
# 36
# 86
# 26
# 1
